# %% [markdown]
# # 📦 UN Comtrade 무역 데이터 분석
#
# > **실습 목표**
# > 1. UN Comtrade에서 내려받은 무역 데이터를 불러오고 구조를 파악합니다.
# > 2. 열 선택, 정렬, 필터링 등 기본 조작을 함수별로 연습합니다.
# > 3. 결측치 처리와 파생변수 생성을 익힙니다.
# > 4. 그룹 집계와 중복 처리, 시각화를 체험합니다.
#
# ---
#
# ### 📋 데이터 개요
#
# | 컬럼명 | 설명 |
# |:---|:---|
# | **연도** | 신고 연도 (2020~2024) |
# | **교역상대국** | 수출·수입 상대국 (China, USA, Viet Nam) |
# | **수출입구분** | Export(수출) / Import(수입) |
# | **HS코드** | 4자리 HS 품목 코드 |
# | **품목명** | HS 코드에 해당하는 품목 설명 |
# | **수량단위** | 수량의 단위 (u=개, kg 등) |
# | **수량** | 수출·수입 수량 |
# | **순중량(kg)** | 포장 제외 순 중량 |
# | **CIF금액(\$)** | Cost+Insurance+Freight (수입 통관 기준) |
# | **FOB금액(\$)** | Free on Board (수출 통관 기준) |
# | **교역금액(\$)** | 실제 활용 교역 금액 (수출=FOB, 수입=CIF) |
# | **HS분류버전** | HS 협약 버전 (H5 = 2022년 기준) |

# %% [markdown]
# ---
# ## 0. 한글 폰트 설치 (Google Colab 사용 시)
#
# 그래프에서 한글이 깨지는 것을 방지합니다.
# 아래 셀 실행 후 **런타임 → 세션 다시 시작** 을 눌러주세요.

# %%
# Google Colab 환경에서만 실행
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,430 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ---
# ## 1. 라이브러리 불러오기
#
# 분석에 필요한 패키지를 가장 먼저 가져옵니다.
#
# | 라이브러리 | 역할 |
# |:---|:---|
# | `pandas` | 표(DataFrame) 형태로 데이터를 다루는 핵심 도구 |
# | `numpy` | 수치 계산·결측치(NaN) 처리 |
# | `matplotlib` | 그래프 기본 설정 |
# | `seaborn` | 통계 시각화 라이브러리 |

# %%
import numpy as np




# 한글 폰트 및 마이너스 기호 설정
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# 숫자 표시 형식: 지수 표기 대신 일반 숫자로
pd.options.display.float_format = '{:,.0f}'.format

print("라이브러리 불러오기 완료!")
# Out:
# 라이브러리 불러오기 완료!

# %% [markdown]
# ---
# ## 2. 데이터 불러오기 — `pd.read_excel()`
#
# 엑셀 파일을 pandas **DataFrame**으로 읽어옵니다.

# %%
# 데이터 다운로드
# !gdown 1dX3xEJdVwjoG6XywPEFy9WoboAK6EIKp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dX3xEJdVwjoG6XywPEFy9WoboAK6EIKp
# To: /content/TradeData.xlsx
# 100% 3.43M/3.43M [00:00<00:00, 167MB/s]

# %%
# 엑셀 파일 불러오기
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 0      2020  Viet Nam  Export  9999
# 1      2020     China  Export  9999
# 2      2020       USA  Export  9999
# 3      2020     China  Export  8601
# 4      2020       USA  Export  6210
# ...     ...       ...     ...   ...
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량   순중량(kg)  \
# 0            Commodities not specified according to kind  NaN   0         0
# 1            Commodities not specified according to kind  NaN   0         0
# 2            Commodities not specified according to kind  NaN   0         0
# 3      Rail locomotives; powered from an external sou...    u   0        30
# 4      Garments made up of fabrics of heading no. 560...  NaN   0    32,964
# ...                                                  ...  ...  ..       ...
# 32090  Regulating or controlling instruments and appa...  NaN   0 7,322,577
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN   0       NaN
# 32092  Vessels and other floating structures; for bre...  NaN   0       NaN
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN   0       NaN
# 32094  Iron ores and concentrates; including roasted ...  NaN   0       NaN
#
#          CIF금액($)    FOB금액($)    교역금액($) HS분류버전
# 0             NaN  12,293,389   12293389     H5
# 1             NaN   3,402,788    3402788     H5
# 2             NaN 166,872,635  166872635     H5
# 3             NaN         429        429     H5
# 4             NaN   1,313,112    1313112     H5
# ...           ...         ...        ...    ...
# 32090 397,176,666         NaN  397176666     H6
# 32091          27         NaN         27     H6
# 32092         879         NaN        879     H6
# 32093       6,405         NaN       6405     H6
# 32094          11         NaN         11     H6
#
# [32095 rows x 12 columns]

# %% [markdown]
# > 💡 **팁**: CSV 파일이라면 `pd.read_csv('파일명.csv', encoding='utf-8')` 를 사용합니다.

# %% [markdown]
# ---
# ## 3. 데이터 기초 확인
#
# ### 3-1. 데이터 크기 — `.shape`
#
# 전체 행(건수)과 열(컬럼) 수를 확인합니다.

# %%
# (행 수, 열 수) 형태로 반환
# Out:
# (32095, 12)

# %% [markdown]
# ### 3-2. 컬럼 목록 — `.columns`

# %%
# 컬럼명 목록 확인
# Out:
# Index(['연도', '교역상대국', '수출입구분', 'HS코드', '품목명', '수량단위', '수량', '순중량(kg)',
#        'CIF금액($)', 'FOB금액($)', '교역금액($)', 'HS분류버전'],
#       dtype='object')

# %% [markdown]
# ### 3-3. 수치형 기술 통계 — `.describe()`

# %%
# 개수, 평균, 표준편차, 최솟값, 사분위수, 최댓값 한눈에 확인
# Out:
#           연도   HS코드             수량        순중량(kg)       CIF금액($)  \
# count 32,095 32,095         32,095         32,057         16,490
# mean   2,022  5,469     23,854,865     25,662,212     70,846,886
# std        1  2,693    338,362,311    339,864,769    506,205,117
# min    2,020    101              0              0              1
# 25%    2,021  2,932            328          9,508        172,337
# 50%    2,022  5,703         65,163        210,746      2,935,250
# 75%    2,023  8,206      1,687,923      2,730,928     25,423,834
# max    2,024  9,999 21,511,870,000 21,511,870,000 23,504,782,880
#
#             FOB금액($)        교역금액($)
# count         15,605         32,095
# mean      96,911,414     83,519,793
# std    1,000,581,576    786,500,481
# min                1              1
# 25%          152,554        161,978
# 50%        2,077,696      2,507,866
# 75%       19,248,976     22,294,190
# max   48,812,087,314 48,812,087,314

# %% [markdown]
# ### 3-4. 앞뒤 행 미리보기 — `.head()` / `.tail()`

# %%
# 처음 5행 확인 (기본값=5, 숫자를 바꾸면 원하는 만큼)
# Out:
#      연도     교역상대국   수출입구분  HS코드  \
# 0  2020  Viet Nam  Export  9999
# 1  2020     China  Export  9999
# 2  2020       USA  Export  9999
# 3  2020     China  Export  8601
# 4  2020       USA  Export  6210
#
#                                                  품목명 수량단위  수량  순중량(kg)  \
# 0        Commodities not specified according to kind  NaN   0        0
# 1        Commodities not specified according to kind  NaN   0        0
# 2        Commodities not specified according to kind  NaN   0        0
# 3  Rail locomotives; powered from an external sou...    u   0       30
# 4  Garments made up of fabrics of heading no. 560...  NaN   0   32,964
#
#    CIF금액($)    FOB금액($)    교역금액($) HS분류버전
# 0       NaN  12,293,389   12293389     H5
# 1       NaN   3,402,788    3402788     H5
# 2       NaN 166,872,635  166872635     H5
# 3       NaN         429        429     H5
# 4       NaN   1,313,112    1313112     H5

# %%
# 마지막 5행 확인
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량   순중량(kg)  \
# 32090  Regulating or controlling instruments and appa...  NaN   0 7,322,577
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN   0       NaN
# 32092  Vessels and other floating structures; for bre...  NaN   0       NaN
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN   0       NaN
# 32094  Iron ores and concentrates; including roasted ...  NaN   0       NaN
#
#          CIF금액($)  FOB금액($)    교역금액($) HS분류버전
# 32090 397,176,666       NaN  397176666     H6
# 32091          27       NaN         27     H6
# 32092         879       NaN        879     H6
# 32093       6,405       NaN       6405     H6
# 32094          11       NaN         11     H6

# %% [markdown]
# ### 3-5. 특정 컬럼의 고유값 확인 — `.unique()` / `.nunique()`
#
# 어떤 국가·연도가 포함되어 있는지 확인합니다.

# %%
# 교역상대국 목록
# Out:
# array(['Viet Nam', 'China', 'USA'], dtype=object)

# %%
# 포함된 연도 목록
# Out:
# array([2020, 2021, 2022, 2023, 2024])

# %%
# 고유한 HS코드가 몇 종류인지 (고유값 개수)
# Out:
# 1228

# %% [markdown]
# ---
# ## 4. 열(컬럼) 선택하기
#
# ### 4-1. 단일 컬럼 선택 — `df['컬럼명']`

# %%
# '교역금액($)' 컬럼만 선택
# Out:
# 0         12293389
# 1          3402788
# 2        166872635
# 3              429
# 4          1313112
#            ...
# 32090    397176666
# 32091           27
# 32092          879
# 32093         6405
# 32094           11
# Name: 교역금액($), Length: 32095, dtype: int64

# %% [markdown]
# ### 4-2. 여러 컬럼 선택 — `df[['컬럼1', '컬럼2', ...]]`

# %%
# 주요 컬럼만 골라서 보기
# Out:
#          연도     교역상대국   수출입구분  HS코드    교역금액($)
# 0      2020  Viet Nam  Export  9999   12293389
# 1      2020     China  Export  9999    3402788
# 2      2020       USA  Export  9999  166872635
# 3      2020     China  Export  8601        429
# 4      2020       USA  Export  6210    1313112
# ...     ...       ...     ...   ...        ...
# 32090  2024     China  Import  9032  397176666
# 32091  2024       USA  Import  2522         27
# 32092  2024       USA  Import  8908        879
# 32093  2024       USA  Import  4103       6405
# 32094  2024  Viet Nam  Import  2601         11
#
# [32095 rows x 5 columns]

# %% [markdown]
# ---
# ## 5. 데이터 정렬 — `sort_values()`

# %%
# 교역금액 기준 내림차순 정렬 (가장 큰 거래부터)
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 12978  2022     China  Export  8542
# 6618   2021     China  Export  8542
# 25889  2024     China  Export  8542
# 388    2020     China  Export  8542
# 28557  2024       USA  Export  8703
# ...     ...       ...     ...   ...
# 20854  2023     China  Export  1005
# 21883  2023       USA  Export  7101
# 21906  2023       USA  Export  3825
# 21683  2023  Viet Nam  Export  4906
# 73     2020       USA  Export  5904
#
#                                                      품목명 수량단위        수량  \
# 12978                     Electronic integrated circuits  NaN         0
# 6618                      Electronic integrated circuits  NaN         0
# 25889                     Electronic integrated circuits  NaN         0
# 388                       Electronic integrated circuits  NaN         0
# 28557  Motor cars and other motor vehicles; principal...    u 1,224,162
# ...                                                  ...  ...       ...
# 20854                                       Maize (corn)   kg         0
# 21883  Pearls; natural or cultured, whether or not wo...   kg         0
# 21906  Residual products of the chemical or allied in...   kg         2
# 21683  Plans and drawings; for architectural, enginee...   kg        12
# 73     Linoleum, whether or not cut to shape; floor c...  NaN         0
#
#             순중량(kg)  CIF금액($)       FOB금액($)      교역금액($) HS분류버전
# 12978     5,362,407       NaN 48,812,087,314  48812087314     H6
# 6618      6,027,861       NaN 46,483,142,951  46483142951     H5
# 25889     4,505,603       NaN 42,264,473,510  42264473510     H6
# 388       5,034,895       NaN 36,220,768,537  36220768537     H5
# 28557 2,347,535,782       NaN 35,247,878,595  35247878595     H6
# ...             ...       ...            ...          ...    ...
# 20854             0       NaN              1            1     H6
# 21883             0       NaN              1            1     H6
# 21906             2       NaN              1            1     H6
# 21683            12       NaN              1            1     H6
# 73               10       NaN              1            1     H5
#
# [32095 rows x 12 columns]

# %%
# 교역금액 기준 오름차순 정렬 (가장 작은 거래부터)
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 73     2020       USA  Export  5904
# 19291  2023  Viet Nam  Export  5904
# 20802  2023     China  Export  7905
# 20854  2023     China  Export  1005
# 21906  2023       USA  Export  3825
# ...     ...       ...     ...   ...
# 28557  2024       USA  Export  8703
# 388    2020     China  Export  8542
# 25889  2024     China  Export  8542
# 6618   2021     China  Export  8542
# 12978  2022     China  Export  8542
#
#                                                      품목명 수량단위        수량  \
# 73     Linoleum, whether or not cut to shape; floor c...  NaN         0
# 19291  Linoleum, whether or not cut to shape; floor c...  NaN         0
# 20802               Zinc; plates, sheets, strip and foil   kg         1
# 20854                                       Maize (corn)   kg         0
# 21906  Residual products of the chemical or allied in...   kg         2
# ...                                                  ...  ...       ...
# 28557  Motor cars and other motor vehicles; principal...    u 1,224,162
# 388                       Electronic integrated circuits  NaN         0
# 25889                     Electronic integrated circuits  NaN         0
# 6618                      Electronic integrated circuits  NaN         0
# 12978                     Electronic integrated circuits  NaN         0
#
#             순중량(kg)  CIF금액($)       FOB금액($)      교역금액($) HS분류버전
# 73               10       NaN              1            1     H5
# 19291             4       NaN              1            1     H6
# 20802             1       NaN              1            1     H6
# 20854             0       NaN              1            1     H6
# 21906             2       NaN              1            1     H6
# ...             ...       ...            ...          ...    ...
# 28557 2,347,535,782       NaN 35,247,878,595  35247878595     H6
# 388       5,034,895       NaN 36,220,768,537  36220768537     H5
# 25889     4,505,603       NaN 42,264,473,510  42264473510     H6
# 6618      6,027,861       NaN 46,483,142,951  46483142951     H5
# 12978     5,362,407       NaN 48,812,087,314  48812087314     H6
#
# [32095 rows x 12 columns]

# %% [markdown]
# ---
# ## 6. 빈도 집계 — `value_counts()`
#
# 특정 컬럼에 어떤 값이 몇 번 나타나는지 셉니다.

# %%
# 교역상대국별 데이터 건수
# Out:
# 교역상대국
# China       11068
# USA         11064
# Viet Nam     9963
# Name: count, dtype: int64

# %%
# 수출입구분별 데이터 건수
# Out:
# 수출입구분
# Import    16490
# Export    15605
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 🏋️ 중간 실습 ① — 기초 확인 · 열 선택 · 정렬 · 빈도 집계
#
# > 앞에서 배운 함수들을 직접 사용해 보세요.
#
# ### 문제 1-1
# 데이터의 전체 **행 수와 열 수**를 출력하고, **컬럼 이름 목록**도 확인하세요.

# %%
# Out:
# (32095, 12)

# %%
# Out:
# Index(['연도', '교역상대국', '수출입구분', 'HS코드', '품목명', '수량단위', '수량', '순중량(kg)',
#        'CIF금액($)', 'FOB금액($)', '교역금액($)', 'HS분류버전'],
#       dtype='object')

# %% [markdown]
# ### 문제 1-2
# `연도`, `교역상대국`, `수출입구분`, `교역금액($)` 컬럼만 선택한 뒤,
# **교역금액 내림차순**으로 정렬해 상위 10행을 출력하세요.

# %%
# Out:
#          연도  교역상대국   수출입구분      교역금액($)
# 12978  2022  China  Export  48812087314
# 6618   2021  China  Export  46483142951
# 25889  2024  China  Export  42264473510
# 388    2020  China  Export  36220768537
# 28557  2024    USA  Export  35247878595
# 19513  2023  China  Export  33178742737
# 22104  2023    USA  Export  32705122291
# 19013  2022  China  Import  23504782880
# 15672  2022    USA  Export  22590244982
# 12434  2021  China  Import  20729679902

# %% [markdown]
# ### 문제 1-3
# `수출입구분` 컬럼에서 **수출(Export)과 수입(Import)이 각각 몇 건**인지 확인하고,
# `HS코드`의 고유한 종류가 **총 몇 가지**인지 출력하세요.

# %%
# Out:
# 수출입구분
# Import    16490
# Export    15605
# Name: count, dtype: int64

# %%
# Out:
# 1228

# %% [markdown]
# ---
# ## 7. 데이터 필터링 (조건 검색)
#
# 관세청 조사 실무에서 가장 자주 사용하는 기능입니다.
#
# ### 7-1. 단일 조건 필터링

# %%
# 중국과의 교역 데이터만 추출
# Out:
#          연도  교역상대국   수출입구분  HS코드  \
# 1      2020  China  Export  9999
# 3      2020  China  Export  8601
# 6      2020  China  Export  7007
# 8      2020  China  Export  2804
# 9      2020  China  Export  8423
# ...     ...    ...     ...   ...
# 32063  2024  China  Import  9507
# 32064  2024  China  Import  9608
# 32065  2024  China  Import  9613
# 32089  2024  China  Import   602
# 32090  2024  China  Import  9032
#
#                                                      품목명 수량단위  수량    순중량(kg)  \
# 1            Commodities not specified according to kind  NaN   0          0
# 3      Rail locomotives; powered from an external sou...    u   0         30
# 6      Safety glass, consisting of toughened (tempere...  NaN   0  1,676,596
# 8              Hydrogen, rare gases and other non-metals  NaN   0 11,739,097
# 9      Weighing machines; excluding balances of a sen...  NaN   0    106,848
# ...                                                  ...  ...  ..        ...
# 32063  Fishing rods, fish-hooks and other line fishin...  NaN   0  5,713,045
# 32064  Pens; ball-point, felt tipped, other porous ti...  NaN   0  3,301,904
# 32065  Cigarette lighters and other lighters, whether...  NaN   0  1,999,109
# 32089  Plants, live; n.e.c. in heading no. 0601, (inc...  NaN   0 73,504,545
# 32090  Regulating or controlling instruments and appa...  NaN   0  7,322,577
#
#          CIF금액($)    FOB금액($)    교역금액($) HS분류버전
# 1             NaN   3,402,788    3402788     H5
# 3             NaN         429        429     H5
# 6             NaN   9,730,196    9730196     H5
# 8             NaN 143,556,522  143556522     H5
# 9             NaN   4,734,429    4734429     H5
# ...           ...         ...        ...    ...
# 32063  78,693,475         NaN   78693475     H6
# 32064  35,743,606         NaN   35743606     H6
# 32065  16,809,570         NaN   16809570     H6
# 32089  54,040,938         NaN   54040938     H6
# 32090 397,176,666         NaN  397176666     H6
#
# [11068 rows x 12 columns]

# %%
# 수입(Import) 데이터만 추출
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 3107   2020  Viet Nam  Import  7005
# 3108   2020       USA  Import  5702
# 3109   2020       USA  Import  6907
# 3110   2020       USA  Import  7005
# 3111   2020  Viet Nam  Import  4403
# ...     ...       ...     ...   ...
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위      수량  \
# 3107   Glass; float glass and surface ground or polis...   m²     589
# 3108   Carpets and other textile floor coverings; wov...   m²  21,632
# 3109   Ceramic flags and paving, hearth or wall tiles...   m²  81,983
# 3110   Glass; float glass and surface ground or polis...   m² 511,885
# 3111   Wood in the rough, whether or not stripped of ...   m³      28
# ...                                                  ...  ...     ...
# 32090  Regulating or controlling instruments and appa...  NaN       0
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN       0
# 32092  Vessels and other floating structures; for bre...  NaN       0
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN       0
# 32094  Iron ores and concentrates; including roasted ...  NaN       0
#
#         순중량(kg)    CIF금액($)  FOB금액($)    교역금액($) HS분류버전
# 3107      1,726       3,944       NaN       3944     H5
# 3108      7,071     250,507       NaN     250507     H5
# 3109    412,105     821,123       NaN     821123     H5
# 3110  3,336,110   3,127,854       NaN    3127854     H5
# 3111     30,236       9,851       NaN       9851     H5
# ...         ...         ...       ...        ...    ...
# 32090 7,322,577 397,176,666       NaN  397176666     H6
# 32091       NaN          27       NaN         27     H6
# 32092       NaN         879       NaN        879     H6
# 32093       NaN       6,405       NaN       6405     H6
# 32094       NaN          11       NaN         11     H6
#
# [16490 rows x 12 columns]

# %%
# 교역금액 1억 달러 이상인 건
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 2      2020       USA  Export  9999
# 8      2020     China  Export  2804
# 10     2020     China  Export  8504
# 30     2020     China  Export  7003
# 109    2020       USA  Export  8526
# ...     ...       ...     ...   ...
# 32084  2024  Viet Nam  Import  8512
# 32085  2024  Viet Nam  Import  8517
# 32087  2024  Viet Nam  Import  8541
# 32088  2024  Viet Nam  Import  8542
# 32090  2024     China  Import  9032
#
#                                                      품목명 수량단위  수량    순중량(kg)  \
# 2            Commodities not specified according to kind  NaN   0          0
# 8              Hydrogen, rare gases and other non-metals  NaN   0 11,739,097
# 10     Electric transformers, static converters (e.g....  NaN   0 15,747,054
# 30     Glass; cast glass and rolled glass in sheets o...  NaN   0 66,402,802
# 109    Radar apparatus, radio navigational aid appara...  NaN   0    704,492
# ...                                                  ...  ...  ..        ...
# 32084  Lighting or visual signalling equipment (exclu...  NaN   0  4,428,014
# 32085  Telephone sets, including smartphones and othe...  NaN   0  8,729,036
# 32087  Semiconductor devices (e.g. diodes, transistor...  NaN   0    536,138
# 32088                     Electronic integrated circuits  NaN   0     61,264
# 32090  Regulating or controlling instruments and appa...  NaN   0  7,322,577
#
#            CIF금액($)    FOB금액($)     교역금액($) HS분류버전
# 2               NaN 166,872,635   166872635     H5
# 8               NaN 143,556,522   143556522     H5
# 10              NaN 370,242,660   370242660     H5
# 30              NaN 230,474,874   230474874     H5
# 109             NaN 103,841,386   103841386     H5
# ...             ...         ...         ...    ...
# 32084   103,420,028         NaN   103420028     H6
# 32085 3,623,908,862         NaN  3623908862     H6
# 32087   170,883,660         NaN   170883660     H6
# 32088   381,523,138         NaN   381523138     H6
# 32090   397,176,666         NaN   397176666     H6
#
# [3327 rows x 12 columns]

# %% [markdown]
# ### 7-2. 복합 조건 필터링 (`&` AND, `|` OR)
#
# > ⚠️ 여러 조건을 합칠 때는 반드시 각 조건을 `( )` 괄호로 감싸세요.

# %%
# 중국에서 수입한 데이터
# Out:
#          연도  교역상대국   수출입구분  HS코드  \
# 3113   2020  China  Import  4403
# 3114   2020  China  Import  4407
# 3120   2020  China  Import  7004
# 3121   2020  China  Import  5704
# 3123   2020  China  Import  5703
# ...     ...    ...     ...   ...
# 32063  2024  China  Import  9507
# 32064  2024  China  Import  9608
# 32065  2024  China  Import  9613
# 32089  2024  China  Import   602
# 32090  2024  China  Import  9032
#
#                                                      품목명 수량단위        수량  \
# 3113   Wood in the rough, whether or not stripped of ...   m³         2
# 3114   Wood sawn or chipped lengthwise, sliced or pee...   m³    82,829
# 3120   Glass; drawn glass and blown glass, in sheets,...   m²    29,059
# 3121   Carpets and other textile floor coverings; of ...   m²   387,081
# 3123   Carpets and other textile floor coverings; tuf...   m² 3,228,116
# ...                                                  ...  ...       ...
# 32063  Fishing rods, fish-hooks and other line fishin...  NaN         0
# 32064  Pens; ball-point, felt tipped, other porous ti...  NaN         0
# 32065  Cigarette lighters and other lighters, whether...  NaN         0
# 32089  Plants, live; n.e.c. in heading no. 0601, (inc...  NaN         0
# 32090  Regulating or controlling instruments and appa...  NaN         0
#
#          순중량(kg)    CIF금액($)  FOB금액($)    교역금액($) HS분류버전
# 3113       1,844       7,389       NaN       7389     H5
# 3114  49,945,048  69,932,434       NaN   69932434     H5
# 3120      62,936     683,398       NaN     683398     H5
# 3121     693,976   1,601,913       NaN    1601913     H5
# 3123   9,143,201  29,104,508       NaN   29104508     H5
# ...          ...         ...       ...        ...    ...
# 32063  5,713,045  78,693,475       NaN   78693475     H6
# 32064  3,301,904  35,743,606       NaN   35743606     H6
# 32065  1,999,109  16,809,570       NaN   16809570     H6
# 32089 73,504,545  54,040,938       NaN   54040938     H6
# 32090  7,322,577 397,176,666       NaN  397176666     H6
#
# [5866 rows x 12 columns]

# %%
# 2023년 또는 2024년 데이터
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 19181  2023       USA  Export  9999
# 19182  2023  Viet Nam  Export  9999
# 19183  2023     China  Export  9999
# 19184  2023     China  Export   101
# 19185  2023       USA  Export  8606
# ...     ...       ...     ...   ...
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량   순중량(kg)  \
# 19181        Commodities not specified according to kind  NaN   0         0
# 19182        Commodities not specified according to kind  NaN   0         0
# 19183        Commodities not specified according to kind  NaN   0         0
# 19184             Horses, asses, mules and hinnies; live    u   0         0
# 19185  Railway or tramway goods vans and wagons; not ...    u   0         0
# ...                                                  ...  ...  ..       ...
# 32090  Regulating or controlling instruments and appa...  NaN   0 7,322,577
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN   0       NaN
# 32092  Vessels and other floating structures; for bre...  NaN   0       NaN
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN   0       NaN
# 32094  Iron ores and concentrates; including roasted ...  NaN   0       NaN
#
#          CIF금액($)   FOB금액($)    교역금액($) HS분류버전
# 19181         NaN 12,523,093   12523093     H6
# 19182         NaN  3,008,826    3008826     H6
# 19183         NaN  4,008,742    4008742     H6
# 19184         NaN          1          1     H6
# 19185         NaN         13         13     H6
# ...           ...        ...        ...    ...
# 32090 397,176,666        NaN  397176666     H6
# 32091          27        NaN         27     H6
# 32092         879        NaN        879     H6
# 32093       6,405        NaN       6405     H6
# 32094          11        NaN         11     H6
#
# [12914 rows x 12 columns]

# %% [markdown]
# ### 7-3. 목록 기반 필터링 — `.isin()`

# %%
# 중국 또는 베트남과의 교역 데이터
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 0      2020  Viet Nam  Export  9999
# 1      2020     China  Export  9999
# 3      2020     China  Export  8601
# 5      2020  Viet Nam  Export  9403
# 6      2020     China  Export  7007
# ...     ...       ...     ...   ...
# 32087  2024  Viet Nam  Import  8541
# 32088  2024  Viet Nam  Import  8542
# 32089  2024     China  Import   602
# 32090  2024     China  Import  9032
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량    순중량(kg)  \
# 0            Commodities not specified according to kind  NaN   0          0
# 1            Commodities not specified according to kind  NaN   0          0
# 3      Rail locomotives; powered from an external sou...    u   0         30
# 5      Furniture and parts thereof, n.e.c. in chapter 94  NaN   0  1,059,289
# 6      Safety glass, consisting of toughened (tempere...  NaN   0  1,676,596
# ...                                                  ...  ...  ..        ...
# 32087  Semiconductor devices (e.g. diodes, transistor...  NaN   0    536,138
# 32088                     Electronic integrated circuits  NaN   0     61,264
# 32089  Plants, live; n.e.c. in heading no. 0601, (inc...  NaN   0 73,504,545
# 32090  Regulating or controlling instruments and appa...  NaN   0  7,322,577
# 32094  Iron ores and concentrates; including roasted ...  NaN   0        NaN
#
#          CIF금액($)   FOB금액($)    교역금액($) HS분류버전
# 0             NaN 12,293,389   12293389     H5
# 1             NaN  3,402,788    3402788     H5
# 3             NaN        429        429     H5
# 5             NaN  5,392,159    5392159     H5
# 6             NaN  9,730,196    9730196     H5
# ...           ...        ...        ...    ...
# 32087 170,883,660        NaN  170883660     H6
# 32088 381,523,138        NaN  381523138     H6
# 32089  54,040,938        NaN   54040938     H6
# 32090 397,176,666        NaN  397176666     H6
# 32094          11        NaN         11     H6
#
# [21031 rows x 12 columns]

# %%
# 특정 HS코드 목록 조회 (예: 반도체 관련 코드)
target_hs = [8541, 8542, 8543]
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 145    2020  Viet Nam  Export  8541
# 249    2020       USA  Export  8542
# 250    2020       USA  Export  8543
# 312    2020     China  Export  8541
# 346    2020  Viet Nam  Export  8542
# ...     ...       ...     ...   ...
# 31892  2024  Viet Nam  Import  8543
# 31949  2024       USA  Import  8543
# 31968  2024     China  Import  8543
# 32087  2024  Viet Nam  Import  8541
# 32088  2024  Viet Nam  Import  8542
#
#                                                      품목명 수량단위  수량    순중량(kg)  \
# 145    Diodes, transistors, similar semiconductor dev...  NaN   0  2,574,869
# 249                       Electronic integrated circuits  NaN   0    334,292
# 250    Electrical machines and apparatus; having indi...  NaN   0  3,095,182
# 312    Diodes, transistors, similar semiconductor dev...  NaN   0  4,738,378
# 346                       Electronic integrated circuits  NaN   0  1,540,920
# ...                                                  ...  ...  ..        ...
# 31892  Electrical machines and apparatus; having indi...  NaN   0  1,327,718
# 31949  Electrical machines and apparatus; having indi...  NaN   0    348,295
# 31968  Electrical machines and apparatus; having indi...  NaN   0 13,940,226
# 32087  Semiconductor devices (e.g. diodes, transistor...  NaN   0    536,138
# 32088                     Electronic integrated circuits  NaN   0     61,264
#
#          CIF금액($)       FOB금액($)      교역금액($) HS분류버전
# 145           NaN    975,380,619    975380619     H5
# 249           NaN  1,198,944,849   1198944849     H5
# 250           NaN    181,987,699    181987699     H5
# 312           NaN  1,286,912,705   1286912705     H5
# 346           NaN 10,380,188,073  10380188073     H5
# ...           ...            ...          ...    ...
# 31892  91,641,028            NaN     91641028     H6
# 31949 230,899,997            NaN    230899997     H6
# 31968 647,576,077            NaN    647576077     H6
# 32087 170,883,660            NaN    170883660     H6
# 32088 381,523,138            NaN    381523138     H6
#
# [90 rows x 12 columns]

# %% [markdown]
# ### 7-4. 문자열 포함 여부 — `.str.contains()`

# %%
# 품목명에 'semiconductor' 포함된 건 검색
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 123    2020       USA  Export  8486
# 145    2020  Viet Nam  Export  8541
# 236    2020  Viet Nam  Export  8486
# 274    2020     China  Export  8486
# 312    2020     China  Export  8541
# 405    2020       USA  Export  8541
# 6072   2020     China  Import  8541
# 6159   2020       USA  Import  8541
# 6177   2020  Viet Nam  Import  8541
# 6280   2020     China  Import  8486
# 6339   2020  Viet Nam  Import  8486
# 6346   2020       USA  Import  8486
# 6537   2021       USA  Export  8486
# 6545   2021  Viet Nam  Export  8486
# 6558   2021     China  Export  8486
# 6575   2021  Viet Nam  Export  8541
# 6643   2021       USA  Export  8541
# 6655   2021     China  Export  8541
# 12461  2021       USA  Import  8486
# 12467  2021  Viet Nam  Import  8486
# 12517  2021       USA  Import  8541
# 12611  2021  Viet Nam  Import  8541
# 12693  2021     China  Import  8486
# 12706  2021     China  Import  8541
# 12912  2022  Viet Nam  Export  8486
# 12918  2022  Viet Nam  Export  8541
# 12971  2022     China  Export  8486
# 12977  2022     China  Export  8541
# 13039  2022       USA  Export  8486
# 13104  2022       USA  Export  8541
# 18680  2022  Viet Nam  Import  8486
# 18827  2022     China  Import  8486
# 18853  2022  Viet Nam  Import  8541
# 18881  2022       USA  Import  8486
# 19141  2022     China  Import  8541
# 19153  2022       USA  Import  8541
# 19364  2023  Viet Nam  Export  8486
# 19369  2023  Viet Nam  Export  8541
# 19506  2023     China  Export  8486
# 19512  2023     China  Export  8541
# 19564  2023       USA  Export  8486
# 19570  2023       USA  Export  8541
# 25193  2023       USA  Import  8541
# 25420  2023  Viet Nam  Import  8486
# 25426  2023  Viet Nam  Import  8541
# 25543  2023       USA  Import  8486
# 25555  2023     China  Import  8541
# 25616  2023     China  Import  8486
# 25839  2024  Viet Nam  Export  8541
# 25882  2024     China  Export  8486
# 25888  2024     China  Export  8541
# 26008  2024       USA  Export  8486
# 26014  2024       USA  Export  8541
# 26057  2024  Viet Nam  Export  8486
# 31643  2024       USA  Import  8541
# 31811  2024       USA  Import  8486
# 31876  2024     China  Import  8486
# 31882  2024     China  Import  8541
# 32081  2024  Viet Nam  Import  8486
# 32087  2024  Viet Nam  Import  8541
#
#                                                      품목명 수량단위  수량     순중량(kg)  \
# 123    Machines and apparatus of a kind used solely o...  NaN   0   3,156,259
# 145    Diodes, transistors, similar semiconductor dev...  NaN   0   2,574,869
# 236    Machines and apparatus of a kind used solely o...  NaN   0   1,982,074
# 274    Machines and apparatus of a kind used solely o...  NaN   0  95,973,931
# 312    Diodes, transistors, similar semiconductor dev...  NaN   0   4,738,378
# 405    Diodes, transistors, similar semiconductor dev...  NaN   0 119,163,802
# 6072   Diodes, transistors, similar semiconductor dev...  NaN   0 144,647,888
# 6159   Diodes, transistors, similar semiconductor dev...  NaN   0      98,813
# 6177   Diodes, transistors, similar semiconductor dev...  NaN   0   3,067,139
# 6280   Machines and apparatus of a kind used solely o...  NaN   0   4,829,639
# 6339   Machines and apparatus of a kind used solely o...  NaN   0     499,867
# 6346   Machines and apparatus of a kind used solely o...  NaN   0   8,173,080
# 6537   Machines and apparatus of a kind used solely o...  NaN   0   3,536,829
# 6545   Machines and apparatus of a kind used solely o...  NaN   0   6,106,594
# 6558   Machines and apparatus of a kind used solely o...  NaN   0  86,008,874
# 6575   Diodes, transistors, similar semiconductor dev...  NaN   0   1,819,127
# 6643   Diodes, transistors, similar semiconductor dev...  NaN   0 108,320,898
# 6655   Diodes, transistors, similar semiconductor dev...  NaN   0   7,275,657
# 12461  Machines and apparatus of a kind used solely o...  NaN   0   9,929,817
# 12467  Machines and apparatus of a kind used solely o...  NaN   0   1,105,181
# 12517  Diodes, transistors, similar semiconductor dev...  NaN   0      49,709
# 12611  Diodes, transistors, similar semiconductor dev...  NaN   0     471,501
# 12693  Machines and apparatus of a kind used solely o...  NaN   0   4,917,784
# 12706  Diodes, transistors, similar semiconductor dev...  NaN   0 126,828,480
# 12912  Machines and apparatus of a kind used solely o...  NaN   0   3,179,031
# 12918  Semiconductor devices (e.g. diodes, transistor...  NaN   0   1,295,555
# 12971  Machines and apparatus of a kind used solely o...  NaN   0  53,130,480
# 12977  Semiconductor devices (e.g. diodes, transistor...  NaN   0   8,484,487
# 13039  Machines and apparatus of a kind used solely o...  NaN   0   4,664,708
# 13104  Semiconductor devices (e.g. diodes, transistor...  NaN   0 200,460,970
# 18680  Machines and apparatus of a kind used solely o...  NaN   0   2,109,389
# 18827  Machines and apparatus of a kind used solely o...  NaN   0   6,379,606
# 18853  Semiconductor devices (e.g. diodes, transistor...  NaN   0     810,814
# 18881  Machines and apparatus of a kind used solely o...  NaN   0   9,992,825
# 19141  Semiconductor devices (e.g. diodes, transistor...  NaN   0           0
# 19153  Semiconductor devices (e.g. diodes, transistor...  NaN   0           0
# 19364  Machines and apparatus of a kind used solely o...  NaN   0   7,118,616
# 19369  Semiconductor devices (e.g. diodes, transistor...  NaN   0   1,245,577
# 19506  Machines and apparatus of a kind used solely o...  NaN   0  35,817,039
# 19512  Semiconductor devices (e.g. diodes, transistor...  NaN   0   2,507,583
# 19564  Machines and apparatus of a kind used solely o...  NaN   0   5,493,530
# 19570  Semiconductor devices (e.g. diodes, transistor...  NaN   0 175,532,177
# 25193  Semiconductor devices (e.g. diodes, transistor...  NaN   0   1,217,456
# 25420  Machines and apparatus of a kind used solely o...  NaN   0     829,774
# 25426  Semiconductor devices (e.g. diodes, transistor...  NaN   0     540,314
# 25543  Machines and apparatus of a kind used solely o...  NaN   0   7,914,263
# 25555  Semiconductor devices (e.g. diodes, transistor...  NaN   0 131,856,819
# 25616  Machines and apparatus of a kind used solely o...  NaN   0   4,482,975
# 25839  Semiconductor devices (e.g. diodes, transistor...  NaN   0   1,348,937
# 25882  Machines and apparatus of a kind used solely o...  NaN   0  37,025,661
# 25888  Semiconductor devices (e.g. diodes, transistor...  NaN   0   2,287,562
# 26008  Machines and apparatus of a kind used solely o...  NaN   0   9,099,053
# 26014  Semiconductor devices (e.g. diodes, transistor...  NaN   0  25,260,893
# 26057  Machines and apparatus of a kind used solely o...  NaN   0   2,744,551
# 31643  Semiconductor devices (e.g. diodes, transistor...  NaN   0   1,296,561
# 31811  Machines and apparatus of a kind used solely o...  NaN   0   6,385,118
# 31876  Machines and apparatus of a kind used solely o...  NaN   0   5,763,005
# 31882  Semiconductor devices (e.g. diodes, transistor...  NaN   0 173,763,463
# 32081  Machines and apparatus of a kind used solely o...  NaN   0     383,936
# 32087  Semiconductor devices (e.g. diodes, transistor...  NaN   0     536,138
#
#            CIF금액($)      FOB금액($)     교역금액($) HS분류버전
# 123             NaN   577,364,124   577364124     H5
# 145             NaN   975,380,619   975380619     H5
# 236             NaN   161,114,481   161114481     H5
# 274             NaN 5,766,588,822  5766588822     H5
# 312             NaN 1,286,912,705  1286912705     H5
# 405             NaN 1,026,077,177  1026077177     H5
# 6072  1,809,709,242           NaN  1809709242     H5
# 6159    178,677,901           NaN   178677901     H5
# 6177    153,657,129           NaN   153657129     H5
# 6280    170,375,907           NaN   170375907     H5
# 6339     16,334,800           NaN    16334800     H5
# 6346  4,154,303,283           NaN  4154303283     H5
# 6537            NaN   619,266,392   619266392     H5
# 6545            NaN   336,906,911   336906911     H5
# 6558            NaN 5,714,808,290  5714808290     H5
# 6575            NaN 1,176,820,303  1176820303     H5
# 6643            NaN   866,061,987   866061987     H5
# 6655            NaN 1,537,880,798  1537880798     H5
# 12461 5,972,741,742           NaN  5972741742     H5
# 12467    25,596,397           NaN    25596397     H5
# 12517   192,563,507           NaN   192563507     H5
# 12611   181,685,517           NaN   181685517     H5
# 12693   216,291,129           NaN   216291129     H5
# 12706 2,062,674,822           NaN  2062674822     H5
# 12912           NaN   307,050,420   307050420     H6
# 12918           NaN   760,534,001   760534001     H6
# 12971           NaN 3,873,980,545  3873980545     H6
# 12977           NaN 1,105,396,680  1105396680     H6
# 13039           NaN   766,332,754   766332754     H6
# 13104           NaN 1,568,359,484  1568359484     H6
# 18680    30,097,922           NaN    30097922     H6
# 18827   288,388,455           NaN   288388455     H6
# 18853   191,626,774           NaN   191626774     H6
# 18881 5,256,785,029           NaN  5256785029     H6
# 19141 2,030,882,595           NaN  2030882595     H6
# 19153   187,972,453           NaN   187972453     H6
# 19364           NaN   389,550,456   389550456     H6
# 19369           NaN   812,209,494   812209494     H6
# 19506           NaN 2,974,819,144  2974819144     H6
# 19512           NaN 1,015,569,503  1015569503     H6
# 19564           NaN   716,390,823   716390823     H6
# 19570           NaN 1,181,009,000  1181009000     H6
# 25193   165,694,629           NaN   165694629     H6
# 25420    22,072,818           NaN    22072818     H6
# 25426   161,030,830           NaN   161030830     H6
# 25543 3,882,385,885           NaN  3882385885     H6
# 25555 1,886,691,979           NaN  1886691979     H6
# 25616   207,946,380           NaN   207946380     H6
# 25839           NaN   953,595,109   953595109     H6
# 25882           NaN 3,931,245,871  3931245871     H6
# 25888           NaN 1,054,625,907  1054625907     H6
# 26008           NaN 1,003,937,919  1003937919     H6
# 26014           NaN   690,101,826   690101826     H6
# 26057           NaN   212,618,516   212618516     H6
# 31643   127,830,397           NaN   127830397     H6
# 31811 3,663,220,821           NaN  3663220821     H6
# 31876   397,048,539           NaN   397048539     H6
# 31882 1,580,442,661           NaN  1580442661     H6
# 32081    30,227,747           NaN    30227747     H6
# 32087   170,883,660           NaN   170883660     H6

# %%
# 품목명에 'vehicle' 또는 'motor' 포함된 건 검색 (| 로 OR 조건)
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 12     2020       USA  Export  8510
# 36     2020     China  Export  9106
# 49     2020       USA  Export  9106
# 52     2020       USA  Export  8604
# 53     2020       USA  Export  8712
# ...     ...       ...     ...   ...
# 32001  2024  Viet Nam  Import  8716
# 32035  2024     China  Import  8412
# 32066  2024  Viet Nam  Import  8412
# 32083  2024  Viet Nam  Import  8509
# 32084  2024  Viet Nam  Import  8512
#
#                                                      품목명 수량단위  수량    순중량(kg)  \
# 12     Shavers, hair clippers and hair removing appli...  NaN   0      8,145
# 36     Time of day recording apparatus and apparatus ...  NaN   0     22,318
# 49     Time of day recording apparatus and apparatus ...  NaN   0      1,921
# 52     Railway or tramway maintenance or service vehi...  NaN   0        158
# 53     Bicycles and other cycles; including delivery ...  NaN   0     12,976
# ...                                                  ...  ...  ..        ...
# 32001  Trailers and semi-trailers; other vehicles, no...  NaN   0    783,100
# 32035  Engines and motors; n.e.c. (e.g. reaction engi...  NaN   0 22,388,849
# 32066  Engines and motors; n.e.c. (e.g. reaction engi...  NaN   0    174,031
# 32083  Electro-mechanical domestic appliances; with s...  NaN   0     27,797
# 32084  Lighting or visual signalling equipment (exclu...  NaN   0  4,428,014
#
#          CIF금액($)  FOB금액($)    교역금액($) HS분류버전
# 12            NaN   932,524     932524     H5
# 36            NaN   608,100     608100     H5
# 49            NaN   129,477     129477     H5
# 52            NaN    75,669      75669     H5
# 53            NaN   253,366     253366     H5
# ...           ...       ...        ...    ...
# 32001   2,927,544       NaN    2927544     H6
# 32035 164,822,445       NaN  164822445     H6
# 32066   1,066,896       NaN    1066896     H6
# 32083     433,880       NaN     433880     H6
# 32084 103,420,028       NaN  103420028     H6
#
# [724 rows x 12 columns]

# %% [markdown]
# ---
# ## 🏋️ 중간 실습 ② — 필터링
#
# ### 문제 2-1
# 2024년 **베트남(Viet Nam)** 과의 **수입(Import)** 데이터만 추출하고,
# 교역금액 내림차순으로 정렬해서 상위 5행을 출력하세요.

# %%
result =
result.sort_values('교역금액($)', ascending=False).head(5)
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 32085  2024  Viet Nam  Import  8517
# 29997  2024  Viet Nam  Import  8473
# 30006  2024  Viet Nam  Import  8544
# 28932  2024  Viet Nam  Import  8471
# 29542  2024  Viet Nam  Import  8529
#
#                                                      품목명 수량단위         수량  \
# 32085  Telephone sets, including smartphones and othe...  NaN          0
# 29997  Machinery; parts and accessories (other than c...   kg  1,868,038
# 30006  Insulated wire, cable and other electric condu...   kg 56,234,294
# 28932  Automatic data processing machines and units t...    u  2,703,726
# 29542  Transmission apparatus; parts suitable for use...   kg  6,092,451
#
#          순중량(kg)      CIF금액($)  FOB금액($)     교역금액($) HS분류버전
# 32085  8,729,036 3,623,908,862       NaN  3623908862     H6
# 29997  1,868,038 2,812,513,109       NaN  2812513109     H6
# 30006 56,234,294 1,196,190,409       NaN  1196190409     H6
# 28932  2,319,245 1,173,064,643       NaN  1173064643     H6
# 29542  6,092,451   910,357,841       NaN   910357841     H6

# %% [markdown]
# ### 문제 2-2
# 품목명에 **'electric'** 이 포함된 수출 품목을 추출하세요.

# %%
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 3      2020     China  Export  8601
# 10     2020     China  Export  8504
# 12     2020       USA  Export  8510
# 21     2020       USA  Export  8502
# 124    2020       USA  Export  8507
# ...     ...       ...     ...   ...
# 28616  2024       USA  Export  8545
# 28618  2024     China  Export  8533
# 28645  2024  Viet Nam  Export  8545
# 28652  2024       USA  Export  3603
# 28671  2024     China  Export  8306
#
#                                                      품목명 수량단위      수량  \
# 3      Rail locomotives; powered from an external sou...    u       0
# 10     Electric transformers, static converters (e.g....  NaN       0
# 12     Shavers, hair clippers and hair removing appli...  NaN       0
# 21        Electric generating sets and rotary converters  NaN       0
# 124    Electric accumulators, including separators th...  NaN       0
# ...                                                  ...  ...     ...
# 28616  Carbon electrodes, carbon brushes, lamp carbon...   kg 263,480
# 28618  Electrical resistors (including rheostats and ...   kg 848,739
# 28645  Carbon electrodes, carbon brushes, lamp carbon...   kg  73,096
# 28652  Safety fuses; detonating cords; percussion or ...   kg  57,774
# 28671  Bells, gongs and the like; non-electric, statu...   kg   9,891
#
#           순중량(kg)  CIF금액($)      FOB금액($)     교역금액($) HS분류버전
# 3              30       NaN           429         429     H5
# 10     15,747,054       NaN   370,242,660   370242660     H5
# 12          8,145       NaN       932,524      932524     H5
# 21            627       NaN        83,374       83374     H5
# 124   186,183,140       NaN 1,224,306,303  1224306303     H5
# ...           ...       ...           ...         ...    ...
# 28616     263,480       NaN    17,661,622    17661622     H6
# 28618     848,739       NaN    56,504,634    56504634     H6
# 28645      73,096       NaN     2,904,476     2904476     H6
# 28652      57,774       NaN     4,272,380     4272380     H6
# 28671       9,891       NaN       456,576      456576     H6
#
# [707 rows x 12 columns]

# %% [markdown]
# ### 문제 2-3
# HS코드가 **8471, 8473, 8479** 중 하나이고, 교역금액이 **1천만 달러 이상**인 데이터를 추출하세요.

# %%
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 200    2020     China  Export  8479
# 241    2020       USA  Export  8479
# 382    2020  Viet Nam  Export  8479
# 691    2020       USA  Export  8473
# 1828   2020  Viet Nam  Export  8473
# ...     ...       ...     ...   ...
# 30214  2024       USA  Import  8473
# 30975  2024     China  Import  8473
# 31809  2024       USA  Import  8479
# 31874  2024     China  Import  8479
# 32079  2024  Viet Nam  Import  8479
#
#                                                      품목명 수량단위         수량  \
# 200    Machinery and mechanical appliances; having in...  NaN          0
# 241    Machinery and mechanical appliances; having in...  NaN          0
# 382    Machinery and mechanical appliances; having in...  NaN          0
# 691    Machinery; parts and accessories (other than c...   kg  1,644,147
# 1828   Machinery; parts and accessories (other than c...   kg    174,499
# ...                                                  ...  ...        ...
# 30214  Machinery; parts and accessories (other than c...   kg     93,911
# 30975  Machinery; parts and accessories (other than c...   kg 16,899,522
# 31809  Machinery and mechanical appliances; having in...  NaN          0
# 31874  Machinery and mechanical appliances; having in...  NaN          0
# 32079  Machinery and mechanical appliances; having in...  NaN          0
#
#          순중량(kg)      CIF금액($)      FOB금액($)     교역금액($) HS분류버전
# 200   34,865,554           NaN 1,382,217,936  1382217936     H5
# 241   24,813,010           NaN   572,399,277   572399277     H5
# 382   18,110,540           NaN   686,128,870   686128870     H5
# 691    1,644,147           NaN 5,731,672,732  5731672732     H5
# 1828     174,499           NaN   168,199,948   168199948     H5
# ...          ...           ...           ...         ...    ...
# 30214     93,911   137,688,225           NaN   137688225     H6
# 30975 16,899,522 2,264,297,466           NaN  2264297466     H6
# 31809  2,533,518   187,428,441           NaN   187428441     H6
# 31874 46,175,011   572,612,187           NaN   572612187     H6
# 32079  2,395,478    67,755,410           NaN    67755410     H6
#
# [90 rows x 12 columns]

# %% [markdown]
# ---
# ## 8. 결측치 확인과 처리
#
# ### 8-1. 결측치 개수 확인 — `.isna().sum()`

# %%
# 컬럼별 결측치 개수
# Out:
# 연도              0
# 교역상대국           0
# 수출입구분           0
# HS코드            0
# 품목명             0
# 수량단위         4664
# 수량              0
# 순중량(kg)        38
# CIF금액($)    15605
# FOB금액($)    16490
# 교역금액($)         0
# HS분류버전          0
# dtype: int64

# %%
# 결측치가 있는 행만 보기
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 439    2020  Viet Nam  Export  9112
# 440    2020     China  Export  1003
# 441    2020  Viet Nam  Export  8107
# 442    2020       USA  Export  2510
# 6352   2020       USA  Import  7201
# 6810   2021       USA  Export  6801
# 6811   2021       USA  Export  2513
# 6812   2021       USA  Export  2518
# 12753  2021       USA  Import  8606
# 12754  2021       USA  Import  8908
# 12755  2021       USA  Import  1205
# 12756  2021  Viet Nam  Import  2510
# 12757  2021     China  Import  7902
# 13215  2022       USA  Export  2510
# 13216  2022       USA  Export  2307
# 13217  2022  Viet Nam  Export  4503
# 19125  2022       USA  Import  4406
# 19126  2022       USA  Import  2601
# 19629  2023     China  Export  7201
# 19630  2023       USA  Export  6801
# 19631  2023     China  Export  5202
# 19632  2023     China  Export  3825
# 25633  2023  Viet Nam  Import  9702
# 25634  2023       USA  Import  5305
# 25635  2023       USA  Import  2521
# 25636  2023       USA  Import  3103
# 25637  2023       USA  Import  2610
# 26089  2024       USA  Export  3804
# 26090  2024  Viet Nam  Export  2620
# 26091  2024       USA  Export   701
# 26092  2024       USA  Export  2510
# 26093  2024  Viet Nam  Export  8106
# 26094  2024       USA  Export  2604
# 26095  2024       USA  Export  2822
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량  순중량(kg)  \
# 439    Clock cases and cases of a similar type for ot...  NaN   0      NaN
# 440                                               Barley  NaN   0      NaN
# 441    Cadmium; articles thereof, including waste and...  NaN   0      NaN
# 442    Natural calcium phosphates; natural aluminium ...  NaN   0      NaN
# 6352   Pig iron and spiegeleisen in pigs, blocks or o...  NaN   0      NaN
# 6810   Stone; setts, curbstones and flagstones, of na...  NaN   0      NaN
# 6811   Pumice stone; emery; natural corundum, natural...  NaN   0      NaN
# 6812   Dolomite, whether or not calcined or sintered;...  NaN   0      NaN
# 12753  Railway or tramway goods vans and wagons; not ...  NaN   0      NaN
# 12754  Vessels and other floating structures; for bre...  NaN   0      NaN
# 12755         Rape or colza seeds; whether or not broken  NaN   0      NaN
# 12756  Natural calcium phosphates; natural aluminium ...  NaN   0      NaN
# 12757                              Zinc; waste and scrap  NaN   0      NaN
# 13215  Natural calcium phosphates; natural aluminium ...  NaN   0      NaN
# 13216                                   Wine lees; argol  NaN   0      NaN
# 13217                     Cork; articles of natural cork  NaN   0      NaN
# 19125   Railway or tramway sleepers (cross-ties) of wood  NaN   0      NaN
# 19126  Iron ores and concentrates; including roasted ...  NaN   0      NaN
# 19629  Pig iron and spiegeleisen in pigs, blocks or o...  NaN   0      NaN
# 19630  Stone; setts, curbstones and flagstones, of na...  NaN   0      NaN
# 19631  Cotton waste (including yarn waste and garnett...  NaN   0      NaN
# 19632  Residual products of the chemical or allied in...  NaN   0      NaN
# 25633       Engravings, prints and lithographs; original  NaN   0      NaN
# 25634  Coconut, abaca (Manila hemp or Musa textilis N...  NaN   0      NaN
# 25635  Limestone flux; limestone and other calcareous...  NaN   0      NaN
# 25636       Fertilizers; mineral or chemical, phosphatic  NaN   0      NaN
# 25637                     Chromium ores and concentrates  NaN   0      NaN
# 26089  Residual lyes from the manufacture of wood pul...  NaN   0      NaN
# 26090  Slag, ash and residues; (not from the manufact...  NaN   0      NaN
# 26091                         Potatoes; fresh or chilled  NaN   0      NaN
# 26092  Natural calcium phosphates; natural aluminium ...  NaN   0      NaN
# 26093  Bismuth; articles thereof, including waste and...  NaN   0      NaN
# 26094                       Nickel ores and concentrates  NaN   0      NaN
# 26095  Cobalt oxides and hydroxides; commercial cobal...  NaN   0      NaN
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN   0      NaN
# 32092  Vessels and other floating structures; for bre...  NaN   0      NaN
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN   0      NaN
# 32094  Iron ores and concentrates; including roasted ...  NaN   0      NaN
#
#        CIF금액($)  FOB금액($)  교역금액($) HS분류버전
# 439         NaN       583      583     H5
# 440         NaN    47,009    47009     H5
# 441         NaN       244      244     H5
# 442         NaN    48,220    48220     H5
# 6352        463       NaN      463     H5
# 6810        NaN     4,024     4024     H5
# 6811        NaN     3,170     3170     H5
# 6812        NaN       130      130     H5
# 12753     7,642       NaN     7642     H5
# 12754       775       NaN      775     H5
# 12755       254       NaN      254     H5
# 12756        97       NaN       97     H5
# 12757       609       NaN      609     H5
# 13215       NaN    23,850    23850     H6
# 13216       NaN     2,040     2040     H6
# 13217       NaN        80       80     H6
# 19125         5       NaN        5     H6
# 19126       209       NaN      209     H6
# 19629       NaN    38,000    38000     H6
# 19630       NaN     3,834     3834     H6
# 19631       NaN        74       74     H6
# 19632       NaN    13,830    13830     H6
# 25633       536       NaN      536     H6
# 25634     3,386       NaN     3386     H6
# 25635       675       NaN      675     H6
# 25636        18       NaN       18     H6
# 25637    15,572       NaN    15572     H6
# 26089       NaN       452      452     H6
# 26090       NaN    16,095    16095     H6
# 26091       NaN         4        4     H6
# 26092       NaN   213,484   213484     H6
# 26093       NaN       122      122     H6
# 26094       NaN     1,890     1890     H6
# 26095       NaN     8,069     8069     H6
# 32091        27       NaN       27     H6
# 32092       879       NaN      879     H6
# 32093     6,405       NaN     6405     H6
# 32094        11       NaN       11     H6

# %% [markdown]
# ### 8-2. 결측치 채우기 — `.fillna()`

# %%
# 순중량 결측치를 0으로 채우기


# 처리 결과 확인
df['순중량(kg)'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 8-3. 결측치 있는 행 제거 — `.dropna()`

# %%
# CIF금액($) 결측치가 있는 행 제거
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 3107   2020  Viet Nam  Import  7005
# 3108   2020       USA  Import  5702
# 3109   2020       USA  Import  6907
# 3110   2020       USA  Import  7005
# 3111   2020  Viet Nam  Import  4403
# ...     ...       ...     ...   ...
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위      수량  \
# 3107   Glass; float glass and surface ground or polis...   m²     589
# 3108   Carpets and other textile floor coverings; wov...   m²  21,632
# 3109   Ceramic flags and paving, hearth or wall tiles...   m²  81,983
# 3110   Glass; float glass and surface ground or polis...   m² 511,885
# 3111   Wood in the rough, whether or not stripped of ...   m³      28
# ...                                                  ...  ...     ...
# 32090  Regulating or controlling instruments and appa...  NaN       0
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN       0
# 32092  Vessels and other floating structures; for bre...  NaN       0
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN       0
# 32094  Iron ores and concentrates; including roasted ...  NaN       0
#
#         순중량(kg)    CIF금액($)  FOB금액($)    교역금액($) HS분류버전
# 3107      1,726       3,944       NaN       3944     H5
# 3108      7,071     250,507       NaN     250507     H5
# 3109    412,105     821,123       NaN     821123     H5
# 3110  3,336,110   3,127,854       NaN    3127854     H5
# 3111     30,236       9,851       NaN       9851     H5
# ...         ...         ...       ...        ...    ...
# 32090 7,322,577 397,176,666       NaN  397176666     H6
# 32091         0          27       NaN         27     H6
# 32092         0         879       NaN        879     H6
# 32093         0       6,405       NaN       6405     H6
# 32094         0          11       NaN         11     H6
#
# [16490 rows x 12 columns]

# %% [markdown]
# ---
# ## 9. 파생 변수(새 컬럼) 만들기
#
# ### 9-1. 사칙연산으로 새 컬럼 생성

# %%
# kg당 단가(달러) 계산
# 순중량이 0인 경우 나누기 오류 방지를 위해 NaN으로 처리
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 0      2020  Viet Nam  Export  9999
# 1      2020     China  Export  9999
# 2      2020       USA  Export  9999
# 3      2020     China  Export  8601
# 4      2020       USA  Export  6210
# ...     ...       ...     ...   ...
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량   순중량(kg)  \
# 0            Commodities not specified according to kind  NaN   0         0
# 1            Commodities not specified according to kind  NaN   0         0
# 2            Commodities not specified according to kind  NaN   0         0
# 3      Rail locomotives; powered from an external sou...    u   0        30
# 4      Garments made up of fabrics of heading no. 560...  NaN   0    32,964
# ...                                                  ...  ...  ..       ...
# 32090  Regulating or controlling instruments and appa...  NaN   0 7,322,577
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN   0         0
# 32092  Vessels and other floating structures; for bre...  NaN   0         0
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN   0         0
# 32094  Iron ores and concentrates; including roasted ...  NaN   0         0
#
#          CIF금액($)    FOB금액($)    교역금액($) HS분류버전  단가($/kg)
# 0             NaN  12,293,389   12293389     H5       NaN
# 1             NaN   3,402,788    3402788     H5       NaN
# 2             NaN 166,872,635  166872635     H5       NaN
# 3             NaN         429        429     H5        14
# 4             NaN   1,313,112    1313112     H5        40
# ...           ...         ...        ...    ...       ...
# 32090 397,176,666         NaN  397176666     H6        54
# 32091          27         NaN         27     H6       NaN
# 32092         879         NaN        879     H6       NaN
# 32093       6,405         NaN       6405     H6       NaN
# 32094          11         NaN         11     H6       NaN
#
# [32095 rows x 13 columns]

# %% [markdown]
# ### 9-2. 문자열 처리로 새 컬럼 생성 — `.str` 접근자
#
# HS코드 앞 2자리(류, Chapter)를 추출합니다.

# %%
# HS코드를 문자열로 변환 후 앞 2자리 추출
# Out:
#          연도     교역상대국   수출입구분  HS코드  \
# 0      2020  Viet Nam  Export  9999
# 1      2020     China  Export  9999
# 2      2020       USA  Export  9999
# 3      2020     China  Export  8601
# 4      2020       USA  Export  6210
# ...     ...       ...     ...   ...
# 32090  2024     China  Import  9032
# 32091  2024       USA  Import  2522
# 32092  2024       USA  Import  8908
# 32093  2024       USA  Import  4103
# 32094  2024  Viet Nam  Import  2601
#
#                                                      품목명 수량단위  수량   순중량(kg)  \
# 0            Commodities not specified according to kind  NaN   0         0
# 1            Commodities not specified according to kind  NaN   0         0
# 2            Commodities not specified according to kind  NaN   0         0
# 3      Rail locomotives; powered from an external sou...    u   0        30
# 4      Garments made up of fabrics of heading no. 560...  NaN   0    32,964
# ...                                                  ...  ...  ..       ...
# 32090  Regulating or controlling instruments and appa...  NaN   0 7,322,577
# 32091  Quicklime, slaked lime and hydraulic lime; oth...  NaN   0         0
# 32092  Vessels and other floating structures; for bre...  NaN   0         0
# 32093  Raw hides and skins n.e.c in headings no. 4101...  NaN   0         0
# 32094  Iron ores and concentrates; including roasted ...  NaN   0         0
#
#          CIF금액($)    FOB금액($)    교역금액($) HS분류버전  단가($/kg) HS류(2단위)
# 0             NaN  12,293,389   12293389     H5       NaN       99
# 1             NaN   3,402,788    3402788     H5       NaN       99
# 2             NaN 166,872,635  166872635     H5       NaN       99
# 3             NaN         429        429     H5        14       86
# 4             NaN   1,313,112    1313112     H5        40       62
# ...           ...         ...        ...    ...       ...      ...
# 32090 397,176,666         NaN  397176666     H6        54       90
# 32091          27         NaN         27     H6       NaN       25
# 32092         879         NaN        879     H6       NaN       89
# 32093       6,405         NaN       6405     H6       NaN       41
# 32094          11         NaN         11     H6       NaN       26
#
# [32095 rows x 14 columns]

# %%
# 교역상대국 이름을 한글로 변환 (str.replace)
df['교역상대국_한글'] = (
    df['교역상대국']
    .str.replace('China', '중국')
    .str.replace('USA', '미국')
    .str.replace('Viet Nam', '베트남')
)
df[['교역상대국', '교역상대국_한글']].drop_duplicates()
# Out:
#       교역상대국 교역상대국_한글
# 0  Viet Nam      베트남
# 1     China       중국
# 2       USA       미국

# %% [markdown]
# ---
# ## 🏋️ 중간 실습 ③ — 결측치 처리 · 파생변수
#
# ### 문제 3-1
# 전체 컬럼 중 **결측치가 존재하는 컬럼만** 골라서 결측치 개수를 출력하세요.
# *(힌트: `isna().sum()` 결과에서 0보다 큰 것만 필터링)*

# %%
null_counts = df.isna().sum()
null_counts[null_counts > 0]
# Out:
# 수량단위         4664
# CIF금액($)    15605
# FOB금액($)    16490
# 단가($/kg)      116
# dtype: int64

# %% [markdown]
# ### 문제 3-2
# `수출입구분` 컬럼 값이 `'Export'`이면 **'수출'**, `'Import'`이면 **'수입'** 으로 표시하는
# `수출입구분_한글` 컬럼을 만들고, 두 컬럼을 나란히 출력하세요.

# %%
df['수출입구분_한글'] = df['수출입구분'].str.replace('Export', '수출').str.replace('Import', '수입')
df[['수출입구분', '수출입구분_한글']].drop_duplicates()
# Out:
#        수출입구분 수출입구분_한글
# 0     Export       수출
# 3107  Import       수입

# %% [markdown]
# ### 문제 3-3
# `CIF금액($)` 컬럼의 결측치를 **`FOB금액($)` 값으로 채운** 새 컬럼 `CIF_보정`을 만드세요.
# *(힌트: `fillna()`에 다른 컬럼을 인자로 넣을 수 있습니다)*

# %%
df['CIF_보정'] = df['CIF금액($)'].fillna(df['FOB금액($)'])
df[['CIF금액($)', 'FOB금액($)', 'CIF_보정']].head(10)
# Out:
#    CIF금액($)    FOB금액($)      CIF_보정
# 0       NaN  12,293,389  12,293,389
# 1       NaN   3,402,788   3,402,788
# 2       NaN 166,872,635 166,872,635
# 3       NaN         429         429
# 4       NaN   1,313,112   1,313,112
# 5       NaN   5,392,159   5,392,159
# 6       NaN   9,730,196   9,730,196
# 7       NaN     401,822     401,822
# 8       NaN 143,556,522 143,556,522
# 9       NaN   4,734,429   4,734,429

# %% [markdown]
# ---
# ## 10. 그룹별 집계 — `groupby()`
#
# ### 10-1. 단일 그룹 집계

# %%
# 교역상대국별 교역금액 합계
# Out:
# 교역상대국
# China       1393643016747
# USA          883275696772
# Viet Nam     403649053654
# Name: 교역금액($), dtype: int64

# %%
# 연도별 교역금액 합계
# Out:
# 연도
# 2020    442671731175
# 2021    552193020802
# 2022    590358188541
# 2023    534946898673
# 2024    560397927982
# Name: 교역금액($), dtype: int64

# %%
# 수출입구분별 평균 교역금액
# Out:
# 수출입구분
# Export   96,911,414
# Import   70,846,886
# Name: 교역금액($), dtype: float64

# %% [markdown]
# ### 10-2. 복합 그룹 집계

# %%
# 연도 × 수출입구분별 교역금액 합계
# Out:
# 연도    수출입구분
# 2020  Export    255428799382
#       Import    187242931793
# 2021  Export    315940852196
#       Import    236252168606
# 2022  Export    326923569467
#       Import    263434619074
# 2023  Export    294419541796
#       Import    240527356877
# 2024  Export    319589850355
#       Import    240808077627
# Name: 교역금액($), dtype: int64

# %% [markdown]
# ### 10-3. 여러 통계를 한 번에 — `.agg()`

# %%
# 교역상대국별 교역금액의 합계, 평균, 최댓값, 건수
# Out:
#                     sum        mean          max  count
# 교역상대국
# China     1393643016747 125,916,427  48812087314  11068
# USA        883275696772  79,833,306  35247878595  11064
# Viet Nam   403649053654  40,514,810  16596046564   9963

# %%
# HS류(2단위)별 교역금액 합계
# Out:
# HS류(2단위)
# 10     7614616065
# 11      444514634
# 12     6392098020
# 13      999238994
# 14       87448349
#          ...
# 94    19658655273
# 95    10678177663
# 96     4431530426
# 97     1439464468
# 99     1233918497
# Name: 교역금액($), Length: 88, dtype: int64

# %% [markdown]
# ---
# ## 🏋️ 중간 실습 ④ — 그룹 집계
#
# ### 문제 4-1
# **연도별 · 교역상대국별** 교역금액 합계와 거래 건수를 한 번에 구하세요.

# %%
# Out:
#                         sum  count
# 연도   교역상대국
# 2020 China     241449680807   2204
#      USA       132132888477   2180
#      Viet Nam   69089161891   1972
# 2021 China     301540427996   2208
#      USA       169958354123   2198
#      Viet Nam   80694238683   1999
# 2022 China     310365522921   2215
#      USA       192304269089   2224
#      Viet Nam   87688396531   1981
# 2023 China     267509442925   2219
#      USA       188022086998   2225
#      Viet Nam   79415368750   2015
# 2024 China     272777942098   2222
#      USA       200858098085   2237
#      Viet Nam   86761887799   1996

# %% [markdown]
# ### 문제 4-2
# `HS류(2단위)` 기준으로 교역금액 합계를 구하고,
# **상위 5개 류**와 그 합계를 출력하세요.

# %%
# Out:
# HS류(2단위)
# 85    895917908988
# 84    345401447867
# 87    208091070956
# 27    173326241981
# 39    127065906223
# Name: 교역금액($), dtype: int64

# %% [markdown]
# ---
# ## 11. 시각화 — seaborn / matplotlib
#
# ### 11-1. 막대그래프 — 교역상대국별 교역금액

# %%
# 교역상대국 × 수출입구분별 교역금액 합계
bar_data = df.groupby(['교역상대국_한글', '수출입구분'])['교역금액($)'].sum().reset_index()

plt.figure(figsize=(10, 5))

plt.title('교역상대국 × 수출입구분별 교역금액 합계')
plt.ylabel('교역금액 ($)')
plt.xlabel('교역상대국')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11-2. 선그래프 — 연도별 교역금액 추이

# %%
# 연도 × 수출입구분별 교역금액
line_data = df.groupby(['연도', '수출입구분'])['교역금액($)'].sum().reset_index()

plt.figure(figsize=(10, 5))

plt.title('연도별 수출·수입 교역금액 추이')
plt.ylabel('교역금액 ($)')
plt.xticks(df['연도'].unique())
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11-3. 가로 막대그래프 — 상위 10개 HS류 교역금액

# %%
# HS류별 교역금액 합계 상위 10개
top_hs = df.groupby('HS류(2단위)')['교역금액($)'].sum().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(10, 6))

plt.title('HS류(2단위) 기준 교역금액 상위 10개')
plt.xlabel('교역금액 ($)')
plt.ylabel('HS류(2단위)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6092/11772446.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_hs, x='교역금액($)', y='HS류(2단위)', orient='h', palette='Blues_r')

# %% [markdown]
# ### 11-4. 히스토그램 — 교역금액 분포

# %%
# 로그 스케일 적용 (교역금액 편차가 커서)
plt.figure(figsize=(10, 5))

plt.title('교역금액 분포 (로그 스케일)')
plt.xlabel('교역금액 ($) — 로그 스케일')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11-5. 박스플롯 — 교역상대국별 교역금액 분포

# %%
plt.figure(figsize=(10, 5))

plt.title('교역상대국별 교역금액 분포')
plt.yscale('log')  # y축 로그 스케일
plt.ylabel('교역금액 ($) — 로그 스케일')
plt.xlabel('교역상대국')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 12. 종합 실습 🎯
#
# 지금까지 배운 함수들을 활용해 아래 문제를 풀어보세요.
#
# ### 종합 문제 1
# **2024년** 데이터 중 **수출(Export)** 만 필터링한 뒤,
# `연도`, `교역상대국`, `HS코드`, `교역금액($)` 컬럼만 선택하고
# 교역금액 내림차순으로 정렬해 **상위 10건**을 출력하세요.

# %%
# Out:
#          연도     교역상대국  HS코드      교역금액($)
# 25889  2024     China  8542  42264473510
# 28557  2024       USA  8703  35247878595
# 25840  2024  Viet Nam  8542  16596046564
# 28465  2024  Viet Nam  8524  10870807353
# 26568  2024       USA  8473   8221013905
# 27071  2024     China  8529   7106109546
# 26583  2024       USA  8708   7070705834
# 28624  2024     China  2902   5911000691
# 28390  2024       USA  8523   5444406127
# 28686  2024       USA  2710   5142924176

# %% [markdown]
# ### 종합 문제 2
# **교역상대국별** 교역금액 합계를 구하고,
# 결과를 내림차순으로 정렬해서 출력하세요.
# *(힌트: `groupby` + `sum` + `sort_values`)*

# %%
# Out:
# 교역상대국
# China       1393643016747
# USA          883275696772
# Viet Nam     403649053654
# Name: 교역금액($), dtype: int64

# %% [markdown]
# ### 종합 문제 3
# 품목명에 **'steel'** 또는 **'iron'** 이 포함된 품목만 추출하고,
# **수출입구분별 거래 건수**를 확인하세요.
# *(힌트: `str.contains` + `value_counts`)*

# %%
result =
result['수출입구분'].value_counts()
# Out:
# 수출입구분
# Import    895
# Export    871
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 📌 주요 함수 요약표
#
# | 기능 | 함수 | 예시 |
# |:---|:---|:---|
# | 파일 읽기 | `pd.read_excel()` / `pd.read_csv()` | `pd.read_excel('data.xlsx')` |
# | 크기 확인 | `.shape` | `df.shape` |
# | 컬럼 목록 | `.columns` | `df.columns` |
# | 기술통계 | `.describe()` | `df.describe()` |
# | 앞/뒤 보기 | `.head()` / `.tail()` | `df.head(10)` |
# | 고유값 | `.unique()` / `.nunique()` | `df['국가'].unique()` |
# | 컬럼 선택 | `df['컬럼']` / `df[['A','B']]` | `df[['연도','교역금액($)']]` |
# | 정렬 | `.sort_values()` | `df.sort_values('금액', ascending=False)` |
# | 빈도 집계 | `.value_counts()` | `df['국가'].value_counts()` |
# | 단일 조건 필터 | 불리언 인덱싱 | `df[df['연도'] == 2024]` |
# | 복합 조건 필터 | `&` / `\|` | `df[(조건1) & (조건2)]` |
# | 목록 필터 | `.isin()` | `df[df['국가'].isin(['A','B'])]` |
# | 문자열 검색 | `.str.contains()` | `df['품목명'].str.contains('motor')` |
# | 결측치 확인 | `.isna().sum()` | `df.isna().sum()` |
# | 결측치 채우기 | `.fillna()` | `df['col'].fillna(0)` |
# | 결측치 제거 | `.dropna()` | `df.dropna(subset=['col'])` |
# | 새 컬럼 생성 | 직접 할당 | `df['새컬럼'] = df['a'] / df['b']` |
# | 문자열 처리 | `.str` 접근자 | `df['코드'].astype(str).str[:2]` |
# | 그룹 집계 | `.groupby().agg()` | `df.groupby('국가')['금액'].sum()` |
# | 중복 확인 | `.duplicated()` | `df.duplicated().sum()` |
# | 중복 제거 | `.drop_duplicates()` | `df.drop_duplicates(subset=['키'])` |
# | 파일 저장 | `.to_excel()` / `.to_csv()` | `df.to_excel('결과.xlsx', index=False)` |
