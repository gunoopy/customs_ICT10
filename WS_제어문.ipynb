# %% [markdown]
# # [Workshop]
# - 자료구조 응용
# - if 조건문
# - for 반복문

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q1) 외화 금액이 `금액 + 공백 + 통화명` 형식일 때 원화로 환전된 금액을 출력하세요.
# - 외화 금액 예시 : "100 달러" or "20 유로" or "400 엔"

# %% [markdown]
# |통화명|환율|
# |:--:|:--:|
# |달러|1467.27|
# |유로|1584.78|
# |엔|9.74|

# %%
money = '100 달러' # 146727.0 원
# money = '5000 엔' # 48700.0 원
# Out:
# 146727.0 원

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q2) price가 200 이하이고, selected_brand가 k_brand에 포함되면 "노트북을 구매합니다."를 출력하고, 그렇지 않으면 "다음 구매합니다."를 출력하세요.
# - Ex) `price = 190`, `selected_brand = 'Samsung'`, `k_brand = ['Samsung', 'LG']`
#     - 출력 결과 : "노트북을 구매합니다."

# %%
price = 190
selected_brand = 'Samsung'
k_brand = ['Samsung', 'LG']
# Out:
# 노트북을 구매합니다.

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q3) for 반복문을 이용하여 numbers 리스트의 모든 값에 100을 더하여 출력하세요.

# %%
numbers = [1, 2, 3, 4, 5]
# Out:
# 101
# 102
# 103
# 104
# 105

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q4) for 반복문을 이용하여 numbers 리스트의 모든 값에 100을 더한 결과를 new_numbers 리스트에 추가하세요.

# %%
numbers = [1, 2, 3, 4, 5]
new_numbers = []





new_numbers
# Out:
# [101, 102, 103, 104, 105]

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q5) 총 5명 학생의 성적이 다음과 같을 때 시험 점수가 60점 이상이면 "합격입니다.", 그렇지 않으면 "불합격입니다."를 출력하세요.

# %%
scores = [90, 35, 68, 44, 81]
# Out:
# 합격입니다.
# 불합격입니다.
# 합격입니다.
# 불합격입니다.
# 합격입니다.

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q6) for 반복문과 range() 함수를 이용하여 1부터 100까지의 합을 구하세요.

# %%
total = 0




total
# Out:
# 5050

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q7) for 반복문과 range() 함수를 이용하여 1부터 100까지의 홀수의 합을 구하세요.

# %%
total = 0





total
# Out:
# 2500

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# ### Q8) for 반복문과 range() 함수를 이용하여 colors 리스트의 짝수번째 값에 접근해 출력하세요.
# - colors 리스트의 인덱스로 접근

# %%
colors = ['red', 'green', 'blue', 'black', 'orange']
# Out:
# red
# blue
# orange
