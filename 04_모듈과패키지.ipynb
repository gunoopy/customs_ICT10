# %% [markdown]
# # 모듈 (Modules) 및 패키지(Packages)
# - 모듈은 코드의 재사용성을 높이기 위해 관련된 함수, 클래스, 변수 등을 하나의 파일로 묶어 놓은 것을 의미하며 Python 파일(.py)은 하나의 모듈로 간주된다.
# - 다른 모듈에서 정의된 함수를 사용하기 위해서는 import 키워드를 사용하여 모듈을 불러와서 사용할 수 있다.
# - 패키지는 큰 프로젝트를 더 구조적이고 관리하기 쉽게 만들 수 있다.
# - 패키지는 모듈을 논리적으로 묶어놓은 것으로 디렉토리와 하위 디렉토리를 사용하여 계층적으로 구성된다.

# %% [markdown]
# - 방법1. random 모듈 불러오기

# %%
# Out:
# 2

# %% [markdown]
# - 방법2. random 모듈을 rd 이름으로 불러오기

# %%
# Out:
# 2

# %% [markdown]
# - 방법3. random 모듈의 randint 함수만 불러오기

# %%
# Out:
# 1

# %%
# 날짜 시간을 다루는 라이브러리
import datetime
now =
print("점검 일시:", now)
# Out:
# 점검 일시: 2026-04-22 23:46:33.000421

# %%
# 수학 관련 함수를 다루는 라이브러리
import math

# 원주율(pi) 값 출력


# 루트 16의 값 구하기
# Out:
# 3.141592653589793
# 4.0

# %% [markdown]
# # [실습] 모듈

# %%
# os 모듈을 import 하여 os 모듈의 listdir() 함수를 실행하세요.
# Out:
# ['.config', 'sample_data']

# %%
# math 모듈의 sin 함수를 import하여 sin(0) 값을 구하세요.
# Out:
# 0.0

# %% [markdown]
# ### 🎯 Vibe Coding Challenge
# > **Q.** AI에게 물어보세요: "파이썬 `random` 라이브러리를 사용해서 로또 번호 5쌍을 생성하는 함수를 만들어줘."

# %%
import random

def generate_lotto_numbers():






# 함수 실행
generate_lotto_numbers()
# Out:
# 로또 번호 1번째: [10, 11, 18, 27, 32, 44]
# 로또 번호 2번째: [3, 6, 18, 24, 41, 42]
# 로또 번호 3번째: [1, 9, 10, 26, 27, 42]
# 로또 번호 4번째: [7, 9, 12, 21, 29, 41]
# 로또 번호 5번째: [14, 18, 24, 27, 33, 40]
# [[10, 11, 18, 27, 32, 44],
#  [3, 6, 18, 24, 41, 42],
#  [1, 9, 10, 26, 27, 42],
#  [7, 9, 12, 21, 29, 41],
#  [14, 18, 24, 27, 33, 40]]

# %% [markdown]
# ### 🎯 Vibe Coding Master
# > **Q.** 바이브 코딩으로 다음 주제들 중 하나를 선택하여 파이썬 코드를 작성해보세요.
#
# **첫번째 주제: 비트코인 모의투자 게임 (떡상 vs 떡락)**
# ```
# 초기 자본 100만 원. 10일 동안 비트코인을 사고팔아 수익을 내야 합니다. 매일 아침 가격이 -30% ~ +50% 사이로 랜덤 변동합니다.
#
# [요구 사항]
# 사용자가 매일 1.매수 2.매도 3.존버(대기) 중 하나를 입력
# 다음 날 아침 비트코인 변동성에 따라 사용자 보유 현금, 보유 비트코인 계산 및 출력
# 10일 후 사용자의 최종 현황 출력
# ```
#
# **두번째 주제: 점심메뉴 이상형 월드컵**
# ```
# 총 8가지의 점심 메뉴 후보가 담긴 리스트가 있습니다. 토너먼트 대결 방식으로 두 개의 메뉴 중 하나를 선택하여, 마지막까지 살아남은 최종 메뉴를 결정해야 합니다.
#
# [요구 사항]
# 리스트에 8개의 메뉴(예: 김치찌개, 돈가스, 짜장면, 햄버거 등)를 미리 저장 및 랜덤 섞기
# 8강 -> 4강 -> 결승 순서로 진행하며, 두 메뉴를 보여주고 사용자가 1 또는 2를 입력해 선택
# 최종 우승한 메뉴를 출력하고 "오늘의 점심 메뉴는 OOO입니다!" 메시지 출력
# ```
#
# **세번째 주제: MBTI 성격 유형 검사기**
# ```
# 사용자에게 4가지 핵심 질문을 던져 에너지 방향(E/I), 인식(S/N), 판단(T/F), 생활 양식(J/P)을 판별합니다. 답변을 종합하여 최종 MBTI 유형을 알려줍니다.
#
# [요구 사항]
# 4개의 질문(외향 vs 내향, 감각 vs 직관 등)을 순서대로 화면에 출력
# 사용자가 각 질문에 대해 1번 또는 2번 선택지를 입력하면 해당 알파벳을 저장
# 4개의 알파벳을 조합하여 최종 MBTI 유형(예: ENFP)을 완성하고 출력
# (선택) 결과 유형에 대한 간단한 한 줄 코멘트 출력
# ```
#
# **네번째 주제: 로또 당첨 시뮬레이터 (일확천금의 꿈)**
# ```
# 사용자가 입력한 금액만큼 로또를 자동 구매하고, 랜덤으로 추첨된 당첨 번호와 비교하여 실제 당첨 결과를 확인합니다. 1등부터 5등까지의 당첨 횟수와 총 당첨금을 계산합니다.
#
# [요구 사항]
# 구매: 사용자에게 금액을 입력받아 1,000원당 1장씩 로또 번호(1~45 중 6개)를 자동 생성
# 추첨: 이번 회차의 당첨 번호 6개와 보너스 번호 1개를 랜덤 생성 (중복 불가)
# 판정:
# 1등: 6개 일치 / 2등: 5개 + 보너스 일치 / 3등: 5개 일치 / 4등: 4개 일치 / 5등: 3개 일치 (5,000원)
# 당첨금:
# 1등: 20억 / 2등: 5천만 / 3등: 150만 / 4등: 5만 / 5등: 5천
# 결과: 등수별 당첨 횟수와 총 당첨 금액을 합산하여 수익률과 함께 출력
# ```
